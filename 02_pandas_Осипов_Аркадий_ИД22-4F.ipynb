# %% [markdown]
# ## Задачи для совместного разбора

# %%
import pandas as pd

# %% [markdown]
# ## Лабораторная работа №2

# %% [markdown]
# ### Базовые операции с `DataFrame`

# %% [markdown]
# 1.1 В файлах `recipes_sample.csv` и `reviews_sample.csv` находится информация об рецептах блюд и отзывах на эти рецепты соответственно. Загрузите данные из файлов в виде `pd.DataFrame` с названиями `recipes` и `reviews`. Обратите внимание на корректное считывание столбца с индексами в таблице `reviews` (безымянный столбец).

# %%
recipes = pd.read_csv('recipes_sample.csv')
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id   submitted  n_steps  \
# 0               35193  2002-10-25      NaN
# 1               91970  2003-07-26      NaN
# ...

# %%
reviews = pd.read_csv('reviews_sample.csv')
reviews
# Out:
#         Unnamed: 0     user_id  recipe_id        date  rating  \
# 0           370476       21752      57993  2003-05-01       5
# 1           624300      431813     142201  2007-09-16       5
# 2           187037      400708     252013  2008-01-10       4
# 3           706134  2001852463     404716  2017-12-11       5
# 4           312179       95810     129396  2008-03-14       5
# ...            ...         ...        ...         ...     ...
# 126691     1013457     1270706     335534  2009-05-17       4
# 126692      158736     2282344       8701  2012-06-03       0
# 126693     1059834      689540     222001  2008-04-08       5
# 126694      453285  2000242659     354979  2015-06-02       5
# 126695      691207      463435     415599  2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# ...

# %% [markdown]
# 1.2 Для каждой из таблиц выведите основные параметры:
# * количество точек данных (строк);
# * количество столбцов;
# * тип данных каждого столбца.

# %%
print(f'RECIPES Кол-во строк: {recipes.shape[0]}, Кол-во столбцов: {recipes.shape[1]}, Тип данных каждого столбца: {type(recipes)}')
print(f'REVIEWS Кол-во строк: {reviews.shape[0]}, Кол-во столбцов: {reviews.shape[1]}, Тип данных каждого столбца: {type(recipes)}')
# Out:
# RECIPES Кол-во строк: 30000, Кол-во столбцов: 8, Тип данных каждого столбца: <class 'pandas.core.frame.DataFrame'>
# REVIEWS Кол-во строк: 126696, Кол-во столбцов: 6, Тип данных каждого столбца: <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# 1.3 Исследуйте, в каких столбцах таблиц содержатся пропуски. Посчитайте долю строк, содержащих пропуски, в отношении к общему количеству строк.

# %%
print('RECIPES \n', recipes.isna().sum())
print(f'Доля строк к общему количеству: {(recipes.shape[0] - recipes.dropna().shape[0])/recipes.shape[0]}')
print('REVIEWS \n', reviews.isna().sum())
print(f'Доля пропусков к общему кол-ву: {(reviews.shape[0] - reviews.dropna().shape[0])/reviews.shape[0]}')
# Out:
# RECIPES
#  name                  0
# id                    0
# minutes               0
# contributor_id        0
# submitted             0
# n_steps           11190
# description         623
# n_ingredients      8880
# dtype: int64
# Доля строк к общему количеству: 0.5684666666666667
# REVIEWS
#  Unnamed: 0     0
# user_id        0
# recipe_id      0
# date           0
# rating         0
# review        17
# dtype: int64
# Доля пропусков к общему кол-ву: 0.00013417945317926376

# %% [markdown]
# 1.4 Рассчитайте среднее значение для каждого из числовых столбцов (где это имеет смысл).

# %%
print('RECIPES \n',recipes.mean()[[1, 3, 4]])
print('REVIEWS \n',reviews.mean()[[-1]])
# Out:
# RECIPES
#  minutes          123.358133
# n_steps            9.805582
# n_ingredients      9.008286
# dtype: float64
# REVIEWS
#  rating    4.410802
# dtype: float64

# %% [markdown]
# 1.5 Создайте серию из 10 случайных названий рецептов.

# %%
pd.Series(recipes['name'].sample(n=10))
# Out:
# 27781                               tomato bredie
# 18960                            oatmeal crispies
# 24443                     slovakian cabbage bread
# 24772                     sommer s cinnamon mocha
# 27401    the best    spicy sriracha chicken wings
# 28842              very easy hamburger stroganoff
# 24945       southern living s country fried steak
# 21721                     pumpkin parfait squares
# 23047                                 rum cookies
# 101                          1 2 3 4 cake  orange
# Name: name, dtype: object

# %% [markdown]
# 1.6 Измените индекс в таблице `reviews`, пронумеровав строки, начиная с нуля.

# %%
reviews.index = range(0, len(reviews))
reviews
# Out:
#         Unnamed: 0     user_id  recipe_id        date  rating  \
# 0           370476       21752      57993  2003-05-01       5
# 1           624300      431813     142201  2007-09-16       5
# 2           187037      400708     252013  2008-01-10       4
# 3           706134  2001852463     404716  2017-12-11       5
# 4           312179       95810     129396  2008-03-14       5
# ...            ...         ...        ...         ...     ...
# 126691     1013457     1270706     335534  2009-05-17       4
# 126692      158736     2282344       8701  2012-06-03       0
# 126693     1059834      689540     222001  2008-04-08       5
# 126694      453285  2000242659     354979  2015-06-02       5
# 126695      691207      463435     415599  2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# ...

# %% [markdown]
# 1.7 Выведите информацию о рецептах, время выполнения которых не больше 20 минут и кол-во ингредиентов в которых не больше 5.

# %%
recipes[(recipes['minutes'] <= 20) & (recipes['n_ingredients'] <= 5)]
# Out:
#                                                     name      id  minutes  \
# 28                                   quick biscuit bread  302399       20
# 60                         peas  fit for a king or queen  303944       20
# 90                     hawaiian sunrise           mimosa  100837        5
# 91            tasty dish s   banana pudding in 2 minutes  286484        2
# 94                                    1 minute meatballs   11361       13
# ...                                                  ...     ...      ...
# 29873  zip and steam red potatoes with butter and garlic  304922       13
# 29874                          ziplock vanilla ice cream   74250       10
# 29905                      zucchini and corn with cheese  256177       15
# 29980               zucchini with jalapeno monterey jack  320622       10
# 29983                          zucchini with serrano ham  162411       15
#
#        contributor_id   submitted  n_steps  \
# ...

# %% [markdown]
# ### Работа с датами в `pandas`

# %% [markdown]
# 2.1 Преобразуйте столбец `submitted` из таблицы `recipes` в формат времени. Модифицируйте решение задачи 1.1 так, чтобы считать столбец сразу в нужном формате.

# %%
recipes['submitted'] = pd.to_datetime(recipes['submitted'])
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 2.2 Выведите информацию о рецептах, добавленных в датасет не позже 2010 года.

# %%
recipes[recipes['submitted'] <= '2010-01-01']
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29993                     zuni caf zucchini pickles  316950     2895
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# ### Работа со строковыми данными в `pandas`

# %% [markdown]
# 3.1  Добавьте в таблицу `recipes` столбец `description_length`, в котором хранится длина описания рецепта из столбца `description`.

# %%
recipes['description_length'] = recipes['description'].str.len()
recipes
# Out:
#                                                name      id  minutes  \
# 0             George s at the cove  black bean soup   44123       90
# 1                Healthy for them  yogurt popsicles   67664       10
# 2                      I can t believe it s spinach   38798       30
# 3                              Italian  gut busters   35173       45
# 4          Love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie s holey rustic olive and cheddar bread  267661       80
# 29996          Zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   Zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   Zydeco soup  486161       60
# 29999        Cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 3.2 Измените название каждого рецепта в таблице `recipes` таким образом, чтобы каждое слово в названии начиналось с прописной буквы.

# %%
recipes['name'] = recipes['name'].str.capitalize()
recipes
# Out:
#                                                name      id  minutes  \
# 0             George s at the cove  black bean soup   44123       90
# 1                Healthy for them  yogurt popsicles   67664       10
# 2                      I can t believe it s spinach   38798       30
# 3                              Italian  gut busters   35173       45
# 4          Love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie s holey rustic olive and cheddar bread  267661       80
# 29996          Zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   Zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   Zydeco soup  486161       60
# 29999        Cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 3.3 Добавьте в таблицу `recipes` столбец `name_word_count`, в котором хранится количество слов из названии рецепта (считайте, что слова в названии разделяются только пробелами). Обратите внимание, что между словами может располагаться несколько пробелов подряд.

# %%
recipes['name_word_count'] = recipes['name'].apply(lambda i: ' '.join(i.split())).str.split(' ').str.len()
recipes
# Out:
#                                                name      id  minutes  \
# 0             George s at the cove  black bean soup   44123       90
# 1                Healthy for them  yogurt popsicles   67664       10
# 2                      I can t believe it s spinach   38798       30
# 3                              Italian  gut busters   35173       45
# 4          Love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie s holey rustic olive and cheddar bread  267661       80
# 29996          Zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   Zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   Zydeco soup  486161       60
# 29999        Cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# ### Группировки таблиц `pd.DataFrame`

# %% [markdown]
# 4.1 Посчитайте количество рецептов, представленных каждым из участников (`contributor_id`). Какой участник добавил максимальное кол-во рецептов?

# %%
print(recipes['contributor_id'].value_counts(sort = True))
# Out:
# 89831      421
# 37449      346
# 37779      345
# 1533       186
# 169430     183
#           ...
# 1061628      1
# 1076183      1
# 429061       1
# 64032        1
# 186118       1
# Name: contributor_id, Length: 8404, dtype: int64

# %% [markdown]
# 4.2 Посчитайте средний рейтинг к каждому из рецептов. Для скольких рецептов отсутствуют отзывы? Обратите внимание, что отзыв с нулевым рейтингом или не заполненным текстовым описанием не считается отсутствующим.

# %%
mid_rev = reviews.groupby(['recipe_id'], as_index=False).agg({'rating':'mean'})
print(f'Отсутствуют отзывы для {recipes.shape[0] - mid_rev.shape[0]} рецептов \n Средний рейтинг рецептов \n')
mid_rev
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2092/948809950.py in <module>
# ----> 1 mid_rev = reviews.groupby(['recipe_id'], as_index=False).agg({'rating':'mean'})
#       2 print(f'Отсутствуют отзывы для {recipes.shape[0] - mid_rev.shape[0]} рецептов \n Средний рейтинг рецептов \n')
#       3 mid_rev
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7629         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7630         # "Union[bool, NoDefault]"; expected "bool"
# -> 7631         return DataFrameGroupBy(
#    7632             obj=self,
#    7633             keys=by,
#
# ...

# %% [markdown]
# 4.3 Посчитайте количество рецептов с разбивкой по годам создания.

# %%
recipes.groupby([recipes.submitted.dt.year])['id'].count()
# Out:
# submitted
# 1999     275
# 2000     104
# 2001     589
# 2002    2644
# 2003    2334
# 2004    2153
# 2005    3130
# 2006    3473
# 2007    4429
# 2008    4029
# 2009    2963
# 2010    1538
# 2011     922
# 2012     659
# 2013     490
# 2014     139
# 2015      42
# 2016      24
# 2017      39
# 2018      24
# Name: id, dtype: int64

# %% [markdown]
# ### Объединение таблиц `pd.DataFrame`

# %% [markdown]
# 5.1 При помощи объединения таблиц, создайте `DataFrame`, состоящий из четырех столбцов: `id`, `name`, `user_id`, `rating`. Рецепты, на которые не оставлен ни один отзыв, должны отсутствовать в полученной таблице. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и попытавшись найти строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
reviews.rename(columns={'recipe_id':'id'}, inplace = True)
new_resipes = pd.merge(recipes, reviews, on = 'id', how = 'inner')[['id', 'name', 'user_id', 'rating']]
new_resipes
# Out:
#             id                                               name     user_id  \
# 0        77188  Subru uncle s whole green moong dal i ll be ma...      184447
# 1        77188  Subru uncle s whole green moong dal i ll be ma...      668205
# 2        77188  Subru uncle s whole green moong dal i ll be ma...      843746
# 3        77188  Subru uncle s whole green moong dal i ll be ma...      507469
# 4        77188  Subru uncle s whole green moong dal i ll be ma...      719941
# ...        ...                                                ...         ...
# 126691  143615                                           Caramels     1425430
# 126692  143615                                           Caramels      136558
# 126693  143615                                           Caramels  1800106861
# 126694  143615                                           Caramels      302094
# 126695  143615                                           Caramels      646764
#
#         rating
# 0            4
# ...

# %% [markdown]
# 5.2 При помощи объединения таблиц и группировок, создайте `DataFrame`, состоящий из трех столбцов: `recipe_id`, `name`, `review_count`, где столбец `review_count` содержит кол-во отзывов, оставленных на рецепт `recipe_id`. У рецептов, на которые не оставлен ни один отзыв, в столбце `review_count` должен быть указан 0. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и найдя строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
new_resipes = pd.merge(recipes, reviews, on = 'id', how = 'inner')
review_count = new_resipes.groupby(['id', 'name'], as_index = False).agg({'review':'count'}).rename(columns={'review':'review_count'})
review_count
# Out:
#            id                                        name  review_count
# 0          48                            Boston cream pie             2
# 1          55  Betty crocker s southwestern guacamole dip             4
# 2          66                 Black coffee barbecue sauce            18
# 3          91              Brown rice and vegetable pilaf             4
# 4          94                       Blueberry buttertarts             4
# ...       ...                                         ...           ...
# 28095  536547                         Cauliflower ceviche             1
# 28096  536610               Miracle home made puff pastry             1
# 28097  536728                       Gluten free  vegemite             1
# 28098  536729                Creole watermelon feta salad             4
# 28099  536747                          Lemon pom pom cake             4
#
# [28100 rows x 3 columns]

# %% [markdown]
# 5.3. Выясните, рецепты, добавленные в каком году, имеют наименьший средний рейтинг?

# %%
new_tab = pd.merge(recipes, reviews, on = 'id', how = 'inner')
min_rat = new_tab.groupby([new_tab.submitted.dt.year])['rating'].mean()
min_rat[min_rat == min_rat.min()]
# Out:
# submitted
# 2017    2.75
# Name: rating, dtype: float64

# %% [markdown]
# ### Сохранение таблиц `pd.DataFrame`

# %% [markdown]
# 6.1 Отсортируйте таблицу в порядке убывания величины столбца `name_word_count` и сохраните результаты выполнения заданий 3.1-3.3 в csv файл.

# %%
recipes = recipes.sort_values('name_word_count', ascending=[False])
recipes.to_csv('recipes_ans.csv')
recipes_ans = pd.read_csv('recipes_ans.csv')
recipes_ans
# Out:
#        Unnamed: 0                                               name      id  \
# 0           26223  Subru uncle s whole green moong dal i ll be ma...   77188
# 1           26222  Subru uncle s toor ki dal sindhi style  dad  m...   76908
# 2           27876  Top secret recipes version of  i h o p  griddl...  113346
# 3           28083  Tsr version of t g i  friday s black bean soup...  102274
# 4           22778  Roasted garlic stuffed steak with garlic mashe...   38409
# ...           ...                                                ...     ...
# 29995       23016                                             Rotini  207839
# 29996       23063                                             Runzas   55733
# 29997        4340                                             Caesar   52399
# 29998       21111                                           Pomidori  353387
# 29999        4710                                           Caramels  143615
#
# ...

# %% [markdown]
# 6.2 Воспользовавшись `pd.ExcelWriter`, cохраните результаты 5.1 и 5.2 в файл: на лист с названием `Рецепты с оценками` сохраните результаты выполнения 5.1; на лист с названием `Количество отзывов по рецептам` сохраните результаты выполнения 5.2.

# %%
with pd.ExcelWriter("recipes_ex.xlsx") as writer:
    new_resipes.to_excel(writer, sheet_name='Рецепты с оценками', index=False)
    review_count.to_excel(writer, sheet_name='Количество отзывов по рецептам', index=False)

# %%
ex1 = pd.read_excel('recipes_ex.xlsx', sheet_name='Рецепты с оценками')
ex1
# Out:
#             id                                               name     user_id  \
# 0        77188  Subru uncle s whole green moong dal i ll be ma...      184447
# 1        77188  Subru uncle s whole green moong dal i ll be ma...      668205
# 2        77188  Subru uncle s whole green moong dal i ll be ma...      843746
# 3        77188  Subru uncle s whole green moong dal i ll be ma...      507469
# 4        77188  Subru uncle s whole green moong dal i ll be ma...      719941
# ...        ...                                                ...         ...
# 126691  143615                                           Caramels     1425430
# 126692  143615                                           Caramels      136558
# 126693  143615                                           Caramels  1800106861
# 126694  143615                                           Caramels      302094
# 126695  143615                                           Caramels      646764
#
#         rating
# 0            4
# ...

# %%
ex2 = pd.read_excel('recipes_ex.xlsx', sheet_name='Количество отзывов по рецептам')
ex2
# Out:
#            id                                        name  review_count
# 0          48                            Boston cream pie             2
# 1          55  Betty crocker s southwestern guacamole dip             4
# 2          66                 Black coffee barbecue sauce            18
# 3          91              Brown rice and vegetable pilaf             4
# 4          94                       Blueberry buttertarts             4
# ...       ...                                         ...           ...
# 28095  536547                         Cauliflower ceviche             1
# 28096  536610               Miracle home made puff pastry             1
# 28097  536728                       Gluten free  vegemite             1
# 28098  536729                Creole watermelon feta salad             4
# 28099  536747                          Lemon pom pom cake             4
#
# [28100 rows x 3 columns]
